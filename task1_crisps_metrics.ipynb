# %%
   #Karan choudhary  
   #Task1 
   #Perform EDA and apply 3 algorithms on data and then visualize them

# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#loading the dataset on colab through Upload seession stoorage button
#reading the training csv file by hepl of pandas 
data=pd.read_csv('Training.csv')
t_data=pd.read_csv('Testing.csv')

# %%
data.head()
# Out:
#    itching  skin_rash  ...         prognosis  Unnamed: 133
# 0        1          1  ...  Fungal infection           nan
# 1        0          1  ...  Fungal infection           nan
# 2        1          0  ...  Fungal infection           nan
# 3        1          1  ...  Fungal infection           nan
# 4        1          1  ...  Fungal infection           nan
#
# [5 rows x 134 columns]

# %%
len(data.columns)
# Out:
# 134

# %%
data.shape
# Out:
# (4920, 134)

# %%
data.isnull().count() #missingvalues hyper paramter eda from sctarch
# Out:
# itching                 4920
# skin_rash               4920
# nodal_skin_eruptions    4920
# continuous_sneezing     4920
# shivering               4920
#                         ...
# blister                 4920
# red_sore_around_nose    4920
# yellow_crust_ooze       4920
# prognosis               4920
# Unnamed: 133            4920
# Length: 134, dtype: int64

# %%
data.isnull().sum() #missingvalues hyper paramter eda from sctarch
# Out:
# itching                    0
# skin_rash                  0
# nodal_skin_eruptions       0
# continuous_sneezing        0
# shivering                  0
#                         ...
# blister                    0
# red_sore_around_nose       0
# yellow_crust_ooze          0
# prognosis                  0
# Unnamed: 133            4920
# Length: 134, dtype: int64

# %%
#target variable
data['prognosis'].unique()
# Out:
# array(['Fungal infection', 'Allergy', 'GERD', 'Chronic cholestasis',
#        'Drug Reaction', 'Peptic ulcer diseae', 'AIDS', 'Diabetes ',
#        'Gastroenteritis', 'Bronchial Asthma', 'Hypertension ', 'Migraine',
#        'Cervical spondylosis', 'Paralysis (brain hemorrhage)', 'Jaundice',
#        'Malaria', 'Chicken pox', 'Dengue', 'Typhoid', 'hepatitis A',
#        'Hepatitis B', 'Hepatitis C', 'Hepatitis D', 'Hepatitis E',
#        'Alcoholic hepatitis', 'Tuberculosis', 'Common Cold', 'Pneumonia',
#        'Dimorphic hemmorhoids(piles)', 'Heart attack', 'Varicose veins',
#        'Hypothyroidism', 'Hyperthyroidism', 'Hypoglycemia',
#        'Osteoarthristis', 'Arthritis',
#        '(vertigo) Paroymsal  Positional Vertigo', 'Acne',
#        'Urinary tract infection', 'Psoriasis', 'Impetigo'], dtype=object)

# %%
data["prognosis"].value_counts()
# Out:
# Cervical spondylosis                       120
# GERD                                       120
# Impetigo                                   120
# Heart attack                               120
# (vertigo) Paroymsal  Positional Vertigo    120
# hepatitis A                                120
# Migraine                                   120
# Hepatitis B                                120
# Hyperthyroidism                            120
# Diabetes                                   120
# Hepatitis C                                120
# Alcoholic hepatitis                        120
# Chicken pox                                120
# AIDS                                       120
# Psoriasis                                  120
# Hypothyroidism                             120
# Hypoglycemia                               120
# Malaria                                    120
# Dimorphic hemmorhoids(piles)               120
# Gastroenteritis                            120
# ...

# %%
#dropping the Unnamed:133 variable bcz we dont wont any variable with All NAN values
data = data.drop('Unnamed: 133', axis=1)

# %%
data.shape   #earlier it was (4920,134)
# Out:
# (4920, 133)

# %%
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(50, 50))
cmap = sns.light_palette("black",n_colors=6)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=None, center=0,square=True, annot=True, linewidths=.5)

# %%
data_1=data.columns
for f in data_1:
  sns.distplot(a=X[f])
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897         By definition, these are labels unless 'iloc' is passed in.
# -> 2898         Floats are not allowed as the start, step, or stop of the slice.
#    2899
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prognosis'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data=data,color="red",linewidth=0.000000000010)

# %%
data.hist(figsize=(50,50),color='red',grid="-")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2656423250>,
# ...
#       dtype=object)

# %%
X_train = data.drop("prognosis",axis = 1)
y_train = data["prognosis"]
X_test = t_data.drop("prognosis",axis = 1)
y_test = t_data["prognosis"]

# %%
print(X.info(),y[0:20])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Columns: 132 entries, itching to yellow_crust_ooze
# dtypes: int64(132)
# memory usage: 5.0 MB
# None 0     Fungal infection
# 1     Fungal infection
# 2     Fungal infection
# 3     Fungal infection
# 4     Fungal infection
# 5     Fungal infection
# 6     Fungal infection
# 7     Fungal infection
# 8     Fungal infection
# 9     Fungal infection
# 10             Allergy
# 11             Allergy
# 12             Allergy
# 13             Allergy
# 14             Allergy
# 15             Allergy
# 16             Allergy
# 17             Allergy
# 18             Allergy
# 19             Allergy
# Name: prognosis, dtype: object

# %%
print("X_train  size :",X_train.shape,"\nX_test  size",X_test.shape)
print("y_train size ",y_train.shape,"\ny_test size",y_test.shape)
# Out:
# X_train  size : (4920, 132)
# X_test  size (42, 132)
# y_train size  (4920,)
# y_test size (42,)

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression(max_iter = 2)
model1.fit(X_train, y_train)

lr_score = model1.score(X_test, y_test)
Y_pred = model1.predict(X_test)

print("Test Accuracy: {:.2f}%".format(model1.score(X_train, y_train) * 100))
print("Test Accuracy: {:.2f}%".format(model1.score(X_test, y_test) * 100))
# Out:
# Test Accuracy: 97.80%
# Test Accuracy: 95.24%

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier(criterion="entropy")
model2.fit(X_train, y_train)

print("Test Accuracy: {:.2f}%".format(model2.score(X_train, y_train) * 100))
print("Test Accuracy: {:.2f}%".format(model2.score(X_test, y_test) * 100))
dec = model2.score(X_test, y_test)
Y_pred = model2.predict(X_test)
print(Y_pred[0:20])
# Out:
# Test Accuracy: 100.00%
# Test Accuracy: 100.00%
# ['Fungal infection' 'Allergy' 'GERD' 'Chronic cholestasis' 'Drug Reaction'
#  'Peptic ulcer diseae' 'AIDS' 'Diabetes ' 'Gastroenteritis'
#  'Bronchial Asthma' 'Hypertension ' 'Migraine' 'Cervical spondylosis'
#  'Paralysis (brain hemorrhage)' 'Jaundice' 'Malaria' 'Chicken pox'
#  'Dengue' 'Typhoid' 'hepatitis A']

# %%
from sklearn.ensemble import RandomForestClassifier 
model3 = RandomForestClassifier()
model3.fit(X_train, y_train)
rand = model3.score(X_test, y_test)
Y_pred = model3.predict(X_test)

print("Test Accuracy: {:.2f}%".format(model3.score(X_train, y_train) * 100))
print("Test Accuracy: {:.2f}%".format(model3.score(X_test, y_test) * 100))
# Out:
# Test Accuracy: 100.00%
# Test Accuracy: 97.62%

# %%
print("Logistic Regression Accuracy on Test Data",str(lr_score*100))
print("Decision Tree Classifier Accuracy on Test Data",str(dec*100))
print("Random Forest Classifier Accuracy on Test Data",str(rand*100))
# Out:
# Logistic Regression Accuracy on Test Data 95.23809523809523
# Decision Tree Classifier Accuracy on Test Data 100.0
# Random Forest Classifier Accuracy on Test Data 97.61904761904762

# %%
accuracy = [lr_score,dec,rand]
models = ["Logistic Regression","Decision Tree Classifier","Random Forest Classifer"]
plt.figure(figsize = (5,5))
plt.yticks(np.arange(len(accuracy)),models)
plt.xlabel("Accuacy")
plt.ylabel("Algorithms")
plt.title("Algorithms VS TEST ACCUARCY")
plt.barh(np.arange(len(accuracy)),accuracy,color="red")
# Out:
# <BarContainer object of 3 artists>
